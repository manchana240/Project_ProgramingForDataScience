# %%
#Importing necessary libraries
import pandas as pd


#Loading data into a dataframe
df = pd.read_csv('books.csv')
df.head(5) # quickly inspect first 5 rows of data
# Out:
#                                    title    price  stock rating  \
# 0                   A Light in the Attic  Â£51.77     22  Three
# 1                     Tipping the Velvet  Â£53.74     20    One
# 2                             Soumission  Â£50.10     20    One
# 3                          Sharp Objects  Â£47.82     20   Four
# 4  Sapiens: A Brief History of Humankind  Â£54.23     20   Five
#
#                                                 link            category
# 0  http://books.toscrape.com/catalogue/a-light-in...              Poetry
# 1  http://books.toscrape.com/catalogue/tipping-th...  Historical Fiction
# 2  http://books.toscrape.com/catalogue/soumission...             Fiction
# 3  http://books.toscrape.com/catalogue/sharp-obje...             Mystery
# 4  http://books.toscrape.com/catalogue/sapiens-a-...             History

# %%
df.info() #obtaining summary of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     1000 non-null   object
#  1   price     1000 non-null   object
#  2   stock     1000 non-null   int64
#  3   rating    1000 non-null   object
#  4   link      1000 non-null   object
#  5   category  1000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
df.nunique() # understand unique and duplicated values across the columns
# Out:
# title        999
# price        903
# stock         21
# rating         5
# link        1000
# category      50
# dtype: int64

# %%
#further explore duplicated titles to decide whether to remove duplicates or not
duplicate_titles = df[df.duplicated(subset=["title"], keep=False)]
print(duplicate_titles)
# Out:
#                       title    price  stock rating  \
# 236  The Star-Touched Queen  Â£46.02     14   Five
# 358  The Star-Touched Queen  Â£32.30     12   Five
#
#                                                   link category
# 236  http://books.toscrape.com/catalogue/the-star-t...  Fantasy
# 358  http://books.toscrape.com/catalogue/the-star-t...  Fantasy

# %%
# remove irrelevant feilds for analysis 
df = df.drop(['link'], axis =1)
df.head(5)
# Out:
#                                    title    price  stock rating  \
# 0                   A Light in the Attic  Â£51.77     22  Three
# 1                     Tipping the Velvet  Â£53.74     20    One
# 2                             Soumission  Â£50.10     20    One
# 3                          Sharp Objects  Â£47.82     20   Four
# 4  Sapiens: A Brief History of Humankind  Â£54.23     20   Five
#
#              category
# 0              Poetry
# 1  Historical Fiction
# 2             Fiction
# 3             Mystery
# 4             History

# %%
# Extract only digits and decimal points from the price values and coverts to float type
df["price"] = (df["price"].astype(str).str.extract(r'([\d.]+)').astype(float))
df.head(5)
# Out:
#                                    title  price  stock rating  \
# 0                   A Light in the Attic  51.77     22  Three
# 1                     Tipping the Velvet  53.74     20    One
# 2                             Soumission  50.10     20    One
# 3                          Sharp Objects  47.82     20   Four
# 4  Sapiens: A Brief History of Humankind  54.23     20   Five
#
#              category
# 0              Poetry
# 1  Historical Fiction
# 2             Fiction
# 3             Mystery
# 4             History

# %%
#identify how many unique values available in rating
print(df["rating"].unique())
# Out:
# ['Three' 'One' 'Four' 'Five' 'Two']

# %%
#rating conversion
df["rating"] = (
    df["rating"]
    .astype(str)
    .str.strip()
    .str.replace("One", "1")
    .str.replace("Two", "2") 
    .str.replace("Three", "3")
    .str.replace("Four", "4")
    .str.replace("Five", "5")
    .astype(int)
)
df.head(5)
# Out:
#                                    title  price  stock  rating  \
# 0                   A Light in the Attic  51.77     22       3
# 1                     Tipping the Velvet  53.74     20       1
# 2                             Soumission  50.10     20       1
# 3                          Sharp Objects  47.82     20       4
# 4  Sapiens: A Brief History of Humankind  54.23     20       5
#
#              category
# 0              Poetry
# 1  Historical Fiction
# 2             Fiction
# 3             Mystery
# 4             History

# %%
 # Title cleaning :Remove extra spaces, normalize text, strip special characters if present.
df["title"] = df["title"].str.strip()

# %%
#make sure stock values to be numeric
df["stock"] = pd.to_numeric(df["stock"], errors="coerce").astype("Int64")

# %%
#data validation
if df[["title", "price", "rating"]].isnull().any().any():
    raise ValueError("Missing essential values in dataset.")

# %%
df
# Out:
#                                                  title  price  stock  rating  \
# 0                                 A Light in the Attic  51.77     22       3
# 1                                   Tipping the Velvet  53.74     20       1
# 2                                           Soumission  50.10     20       1
# 3                                        Sharp Objects  47.82     20       4
# 4                Sapiens: A Brief History of Humankind  54.23     20       5
# ..                                                 ...    ...    ...     ...
# 995  Alice in Wonderland (Alice's Adventures in Won...  55.53      1       1
# 996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)  57.06      1       4
# 997  A Spy's Devotion (The Regency Spies of London #1)  16.97      1       5
# 998                1st to Die (Women's Murder Club #1)  53.98      1       1
# 999                 1,000 Places to See Before You Die  26.08      1       5
#
#                category
# 0                Poetry
# 1    Historical Fiction
# 2               Fiction
# 3               Mystery
# 4               History
# ..                  ...
# 995            Classics
# 996      Sequential Art
# 997  Historical Fiction
# 998             Mystery
# 999              Travel
#
# [1000 rows x 5 columns]

# %%
#save cleaned data 
df.to_csv("books_clean.csv", index=False)
